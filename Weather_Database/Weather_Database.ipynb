# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests

from citipy import citipy

import os
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip (lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# Create an empty list to hold the weather data.
city_data = []

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | kashary
# Processing Record 2 of Set 1 | havelange
# Processing Record 3 of Set 1 | ngunguru
# Processing Record 4 of Set 1 | kenai
# Processing Record 5 of Set 1 | los chiles
# Processing Record 6 of Set 1 | sept-iles
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | faanui
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 1 | comodoro rivadavia
# Processing Record 12 of Set 1 | goreloye
# Processing Record 13 of Set 1 | pangnirtung
# Processing Record 14 of Set 1 | east london
# Processing Record 15 of Set 1 | touros
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | tuatapere
# Processing Record 18 of Set 1 | kavieng
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | sobolevo
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | san cristobal
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | mercedes
# Processing Record 26 of Set 1 | damietta
# Processing Record 27 of Set 1 | hithadhoo
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | chuy
# Processing Record 30 of Set 1 | cherskiy
# Processing Record 31 of Set 1 | deputatskiy
# Processing Record 32 of Set 1 | lakes entrance
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | calama
# Processing Record 35 of Set 1 | kyren
# Processing Record 36 of Set 1 | kapaa
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | dunapataj
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | qaanaaq
# Processing Record 41 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 1 | ahipara
# Processing Record 43 of Set 1 | hamburg
# Processing Record 44 of Set 1 | naze
# Processing Record 45 of Set 1 | rivera
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | saint-philippe
# Processing Record 49 of Set 1 | beyneu
# Processing Record 50 of Set 1 | svetlogorsk
# Processing Record 1 of Set 2 | ketchikan
# Processing Record 2 of Set 2 | hilo
# Processing Record 3 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | takaka
# Processing Record 7 of Set 2 | innisfail
# Processing Record 8 of Set 2 | kununurra
# Processing Record 9 of Set 2 | lavrentiya
# Processing Record 10 of Set 2 | pitimbu
# Processing Record 11 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 2 | hasaki
# Processing Record 13 of Set 2 | guarapari
# Processing Record 14 of Set 2 | alice springs
# Processing Record 15 of Set 2 | laguna
# Processing Record 16 of Set 2 | luanda
# Processing Record 17 of Set 2 | tasiilaq
# Processing Record 18 of Set 2 | alterosa
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | vanavara
# Processing Record 21 of Set 2 | mahebourg
# Processing Record 22 of Set 2 | mataura
# Processing Record 23 of Set 2 | severo-kurilsk
# Processing Record 24 of Set 2 | tuktoyaktuk
# Processing Record 25 of Set 2 | yellowknife
# Processing Record 26 of Set 2 | lianran
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | castro
# Processing Record 29 of Set 2 | pevek
# Processing Record 30 of Set 2 | provideniya
# Processing Record 31 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 2 | qingdao
# Processing Record 34 of Set 2 | luis correia
# Processing Record 35 of Set 2 | el tigre
# Processing Record 36 of Set 2 | punta arenas
# Processing Record 37 of Set 2 | burnie
# Processing Record 38 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 39 of Set 2 | butaritari
# Processing Record 40 of Set 2 | noyabrsk
# Processing Record 41 of Set 2 | santa cruz do capibaribe
# Processing Record 42 of Set 2 | chokurdakh
# Processing Record 43 of Set 2 | yar-sale
# Processing Record 44 of Set 2 | berlevag
# Processing Record 45 of Set 2 | airai
# Processing Record 46 of Set 2 | vardo
# Processing Record 47 of Set 2 | sao filipe
# Processing Record 48 of Set 2 | tecoanapa
# Processing Record 49 of Set 2 | ler
# Processing Record 50 of Set 2 | flagstaff
# Processing Record 1 of Set 3 | katherine
# Processing Record 2 of Set 3 | oranjemund
# Processing Record 3 of Set 3 | balabac
# Processing Record 4 of Set 3 | waingapu
# Processing Record 5 of Set 3 | gilbues
# Processing Record 6 of Set 3 | portland
# Processing Record 7 of Set 3 | khatanga
# Processing Record 8 of Set 3 | kaitangata
# Processing Record 9 of Set 3 | nichinan
# Processing Record 10 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 3 | dawei
# Processing Record 12 of Set 3 | carnarvon
# Processing Record 13 of Set 3 | ilulissat
# Processing Record 14 of Set 3 | narsaq
# Processing Record 15 of Set 3 | klaksvik
# Processing Record 16 of Set 3 | upernavik
# Processing Record 17 of Set 3 | port alfred
# Processing Record 18 of Set 3 | bluff
# Processing Record 19 of Set 3 | progreso
# Processing Record 20 of Set 3 | iqaluit
# Processing Record 21 of Set 3 | mae hong son
# Processing Record 22 of Set 3 | mehamn
# Processing Record 23 of Set 3 | karratha
# Processing Record 24 of Set 3 | kropotkin
# Processing Record 25 of Set 3 | polyarnyye zori
# Processing Record 26 of Set 3 | belmonte
# Processing Record 27 of Set 3 | villanueva
# Processing Record 28 of Set 3 | boguchar
# Processing Record 29 of Set 3 | dickinson
# Processing Record 30 of Set 3 | katsuura
# Processing Record 31 of Set 3 | kamenka
# Processing Record 32 of Set 3 | sola
# Processing Record 33 of Set 3 | kruisfontein
# Processing Record 34 of Set 3 | simbahan
# Processing Record 35 of Set 3 | kushima
# Processing Record 36 of Set 3 | thompson
# Processing Record 37 of Set 3 | coquimbo
# Processing Record 38 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 39 of Set 3 | urucara
# Processing Record 40 of Set 3 | san patricio
# Processing Record 41 of Set 3 | avarua
# Processing Record 42 of Set 3 | cidreira
# Processing Record 43 of Set 3 | mar del plata
# Processing Record 44 of Set 3 | geraldton
# Processing Record 45 of Set 3 | lebu
# Processing Record 46 of Set 3 | solnechnyy
# Processing Record 47 of Set 3 | newport
# Processing Record 48 of Set 3 | palana
# Processing Record 49 of Set 3 | burley
# Processing Record 50 of Set 3 | half moon bay
# Processing Record 1 of Set 4 | yerbogachen
# Processing Record 2 of Set 4 | kracheh
# City not found. Skipping...
# Processing Record 3 of Set 4 | puerto escondido
# Processing Record 4 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 4 | dryden
# Processing Record 6 of Set 4 | houma
# Processing Record 7 of Set 4 | shilovo
# Processing Record 8 of Set 4 | tarakan
# Processing Record 9 of Set 4 | victoria
# Processing Record 10 of Set 4 | marzuq
# Processing Record 11 of Set 4 | saint george
# Processing Record 12 of Set 4 | arraial do cabo
# Processing Record 13 of Set 4 | arlit
# Processing Record 14 of Set 4 | georgetown
# Processing Record 15 of Set 4 | dingle
# Processing Record 16 of Set 4 | hobart
# Processing Record 17 of Set 4 | taoudenni
# Processing Record 18 of Set 4 | lasa
# Processing Record 19 of Set 4 | isangel
# Processing Record 20 of Set 4 | koutsouras
# Processing Record 21 of Set 4 | nikolskoye
# Processing Record 22 of Set 4 | sorland
# Processing Record 23 of Set 4 | ribeira grande
# Processing Record 24 of Set 4 | bar harbor
# Processing Record 25 of Set 4 | oktyabrskiy
# Processing Record 26 of Set 4 | hambantota
# Processing Record 27 of Set 4 | waipawa
# Processing Record 28 of Set 4 | aswan
# Processing Record 29 of Set 4 | torbay
# Processing Record 30 of Set 4 | bridgetown
# Processing Record 31 of Set 4 | gizo
# Processing Record 32 of Set 4 | namibe
# Processing Record 33 of Set 4 | seidu
# Processing Record 34 of Set 4 | aklavik
# Processing Record 35 of Set 4 | carutapera
# Processing Record 36 of Set 4 | nantucket
# Processing Record 37 of Set 4 | hudson bay
# Processing Record 38 of Set 4 | molteno
# Processing Record 39 of Set 4 | vao
# Processing Record 40 of Set 4 | batagay-alyta
# Processing Record 41 of Set 4 | maloshuyka
# City not found. Skipping...
# Processing Record 42 of Set 4 | buin
# Processing Record 43 of Set 4 | bengkulu
# Processing Record 44 of Set 4 | bereda
# Processing Record 45 of Set 4 | timberlake
# Processing Record 46 of Set 4 | rolla
# Processing Record 47 of Set 4 | san carlos de bariloche
# Processing Record 48 of Set 4 | visnes
# Processing Record 49 of Set 4 | bluefield
# Processing Record 50 of Set 4 | baoqing
# Processing Record 1 of Set 5 | kristianstad
# Processing Record 2 of Set 5 | atambua
# Processing Record 3 of Set 5 | charters towers
# Processing Record 4 of Set 5 | nara
# Processing Record 5 of Set 5 | kanasin
# Processing Record 6 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 5 | longyearbyen
# Processing Record 8 of Set 5 | kortkeros
# Processing Record 9 of Set 5 | asau
# Processing Record 10 of Set 5 | sale
# Processing Record 11 of Set 5 | teguldet
# Processing Record 12 of Set 5 | vila velha
# Processing Record 13 of Set 5 | tiksi
# Processing Record 14 of Set 5 | turbat
# Processing Record 15 of Set 5 | sahaswan
# Processing Record 16 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 5 | karamea
# City not found. Skipping...
# Processing Record 18 of Set 5 | ayabaca
# Processing Record 19 of Set 5 | lata
# Processing Record 20 of Set 5 | makakilo city
# Processing Record 21 of Set 5 | tual
# Processing Record 22 of Set 5 | ombessa
# Processing Record 23 of Set 5 | kenora
# Processing Record 24 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 5 | havre-saint-pierre
# Processing Record 26 of Set 5 | vestmannaeyjar
# Processing Record 27 of Set 5 | shiyan
# Processing Record 28 of Set 5 | yulara
# Processing Record 29 of Set 5 | ukiah
# Processing Record 30 of Set 5 | tambul
# City not found. Skipping...
# Processing Record 31 of Set 5 | nizhniy tsasuchey
# Processing Record 32 of Set 5 | buala
# Processing Record 33 of Set 5 | mae sai
# Processing Record 34 of Set 5 | makat
# Processing Record 35 of Set 5 | sorong
# Processing Record 36 of Set 5 | kimbe
# Processing Record 37 of Set 5 | nanortalik
# Processing Record 38 of Set 5 | road town
# Processing Record 39 of Set 5 | ishikari
# Processing Record 40 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 5 | abu samrah
# Processing Record 42 of Set 5 | saskylakh
# Processing Record 43 of Set 5 | bilibino
# Processing Record 44 of Set 5 | marsa matruh
# Processing Record 45 of Set 5 | san pedro
# Processing Record 46 of Set 5 | inuvik
# Processing Record 47 of Set 5 | medvezhyegorsk
# Processing Record 48 of Set 5 | denpasar
# Processing Record 49 of Set 5 | aratoca
# Processing Record 50 of Set 5 | fort saint james
# Processing Record 1 of Set 6 | guerrero negro
# Processing Record 2 of Set 6 | pingliang
# Processing Record 3 of Set 6 | naraina
# Processing Record 4 of Set 6 | noumea
# Processing Record 5 of Set 6 | san rafael
# Processing Record 6 of Set 6 | tabou
# Processing Record 7 of Set 6 | alegrete
# Processing Record 8 of Set 6 | tarko-sale
# Processing Record 9 of Set 6 | lagoa
# Processing Record 10 of Set 6 | tazovskiy
# Processing Record 11 of Set 6 | conway
# Processing Record 12 of Set 6 | nampula
# Processing Record 13 of Set 6 | carnot
# Processing Record 14 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 15 of Set 6 | ust-tsilma
# Processing Record 16 of Set 6 | cartagena
# Processing Record 17 of Set 6 | ochakiv
# Processing Record 18 of Set 6 | sawakin
# Processing Record 19 of Set 6 | bambous virieux
# Processing Record 20 of Set 6 | shingu
# Processing Record 21 of Set 6 | fortuna
# Processing Record 22 of Set 6 | vidim
# Processing Record 23 of Set 6 | shimoda
# Processing Record 24 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 25 of Set 6 | archena
# Processing Record 26 of Set 6 | santa cruz
# Processing Record 27 of Set 6 | montrose
# Processing Record 28 of Set 6 | coahuayana
# Processing Record 29 of Set 6 | pizarro
# Processing Record 30 of Set 6 | key biscayne
# Processing Record 31 of Set 6 | saquena
# Processing Record 32 of Set 6 | talnakh
# Processing Record 33 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 34 of Set 6 | gornopravdinsk
# Processing Record 35 of Set 6 | safaga
# Processing Record 36 of Set 6 | torgelow
# Processing Record 37 of Set 6 | tucuma
# Processing Record 38 of Set 6 | pedasi
# Processing Record 39 of Set 6 | zykovo
# Processing Record 40 of Set 6 | julio de castilhos
# Processing Record 41 of Set 6 | antofagasta
# Processing Record 42 of Set 6 | kabo
# Processing Record 43 of Set 6 | bethel
# Processing Record 44 of Set 6 | glebychevo
# Processing Record 45 of Set 6 | nandura
# Processing Record 46 of Set 6 | urumqi
# Processing Record 47 of Set 6 | frutal
# Processing Record 48 of Set 6 | araouane
# Processing Record 49 of Set 6 | leh
# Processing Record 50 of Set 6 | bawku
# Processing Record 1 of Set 7 | ulladulla
# Processing Record 2 of Set 7 | ampanihy
# Processing Record 3 of Set 7 | shenjiamen
# Processing Record 4 of Set 7 | san quintin
# Processing Record 5 of Set 7 | puerto rondon
# Processing Record 6 of Set 7 | mitu
# Processing Record 7 of Set 7 | bathsheba
# Processing Record 8 of Set 7 | breytovo
# Processing Record 9 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 7 | kurilsk
# Processing Record 11 of Set 7 | esperance
# Processing Record 12 of Set 7 | omboue
# Processing Record 13 of Set 7 | klyuchi
# Processing Record 14 of Set 7 | nsukka
# Processing Record 15 of Set 7 | baker city
# Processing Record 16 of Set 7 | jatai
# Processing Record 17 of Set 7 | riyadh
# Processing Record 18 of Set 7 | talaya
# Processing Record 19 of Set 7 | ishimbay
# Processing Record 20 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 21 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 22 of Set 7 | nizhnekamsk
# Processing Record 23 of Set 7 | ponta do sol
# Processing Record 24 of Set 7 | mahur
# Processing Record 25 of Set 7 | araria
# Processing Record 26 of Set 7 | swift current
# Processing Record 27 of Set 7 | mehriz
# Processing Record 28 of Set 7 | qaqortoq
# Processing Record 29 of Set 7 | anadyr
# Processing Record 30 of Set 7 | maningrida
# Processing Record 31 of Set 7 | nome
# Processing Record 32 of Set 7 | bonavista
# Processing Record 33 of Set 7 | prince rupert
# Processing Record 34 of Set 7 | vestmanna
# Processing Record 35 of Set 7 | neiafu
# Processing Record 36 of Set 7 | the valley
# Processing Record 37 of Set 7 | tando adam
# Processing Record 38 of Set 7 | rio grande
# Processing Record 39 of Set 7 | luderitz
# Processing Record 40 of Set 7 | norrtalje
# Processing Record 41 of Set 7 | sinjar
# Processing Record 42 of Set 7 | saint-francois
# Processing Record 43 of Set 7 | vaitape
# Processing Record 44 of Set 7 | severo-yeniseyskiy
# Processing Record 45 of Set 7 | norman wells
# Processing Record 46 of Set 7 | gaya
# Processing Record 47 of Set 7 | praia da vitoria
# Processing Record 48 of Set 7 | brae
# Processing Record 49 of Set 7 | manaure
# Processing Record 50 of Set 7 | naryan-mar
# Processing Record 1 of Set 8 | tumut
# Processing Record 2 of Set 8 | spas-demensk
# Processing Record 3 of Set 8 | beringovskiy
# Processing Record 4 of Set 8 | tura
# Processing Record 5 of Set 8 | yuzhne
# Processing Record 6 of Set 8 | khorixas
# Processing Record 7 of Set 8 | fairbanks
# Processing Record 8 of Set 8 | constitucion
# Processing Record 9 of Set 8 | marau
# Processing Record 10 of Set 8 | jonkoping
# Processing Record 11 of Set 8 | labuhan
# Processing Record 12 of Set 8 | kaabong
# Processing Record 13 of Set 8 | margate
# Processing Record 14 of Set 8 | ancud
# Processing Record 15 of Set 8 | cayenne
# Processing Record 16 of Set 8 | port blair
# Processing Record 17 of Set 8 | gyula
# Processing Record 18 of Set 8 | russell
# Processing Record 19 of Set 8 | kuytun
# Processing Record 20 of Set 8 | bosobolo
# Processing Record 21 of Set 8 | santa luzia
# Processing Record 22 of Set 8 | manokwari
# Processing Record 23 of Set 8 | ajaccio
# Processing Record 24 of Set 8 | gamba
# Processing Record 25 of Set 8 | batangafo
# Processing Record 26 of Set 8 | chicla
# Processing Record 27 of Set 8 | port elizabeth
# Processing Record 28 of Set 8 | qesarya
# Processing Record 29 of Set 8 | crotone
# Processing Record 30 of Set 8 | igarka
# Processing Record 31 of Set 8 | mahibadhoo
# Processing Record 32 of Set 8 | sandy bay
# Processing Record 33 of Set 8 | zapolyarnyy
# Processing Record 34 of Set 8 | talcahuano
# Processing Record 35 of Set 8 | kaithal
# Processing Record 36 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 8 | richards bay
# Processing Record 38 of Set 8 | sibolga
# Processing Record 39 of Set 8 | egvekinot
# Processing Record 40 of Set 8 | dombarovskiy
# Processing Record 41 of Set 8 | sal rei
# Processing Record 42 of Set 8 | natchitoches
# Processing Record 43 of Set 8 | mount gambier
# Processing Record 44 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 8 | nokaneng
# Processing Record 46 of Set 8 | pucallpa
# Processing Record 47 of Set 8 | fukue
# Processing Record 48 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 49 of Set 8 | faya
# Processing Record 50 of Set 8 | date
# Processing Record 1 of Set 9 | anton lizardo
# Processing Record 2 of Set 9 | mino
# Processing Record 3 of Set 9 | nanchang
# Processing Record 4 of Set 9 | honningsvag
# Processing Record 5 of Set 9 | lashio
# Processing Record 6 of Set 9 | vancouver
# Processing Record 7 of Set 9 | yumaguzino
# Processing Record 8 of Set 9 | flinders
# Processing Record 9 of Set 9 | goderich
# Processing Record 10 of Set 9 | kruglolesskoye
# Processing Record 11 of Set 9 | matongo
# Processing Record 12 of Set 9 | vila franca do campo
# Processing Record 13 of Set 9 | srednekolymsk
# Processing Record 14 of Set 9 | krasnoselkup
# Processing Record 15 of Set 9 | nouadhibou
# Processing Record 16 of Set 9 | idar
# Processing Record 17 of Set 9 | botou
# Processing Record 18 of Set 9 | baykit
# Processing Record 19 of Set 9 | bay city
# Processing Record 20 of Set 9 | shentala
# Processing Record 21 of Set 9 | omsukchan
# Processing Record 22 of Set 9 | marawi
# Processing Record 23 of Set 9 | sambava
# Processing Record 24 of Set 9 | hirara
# Processing Record 25 of Set 9 | jishou
# Processing Record 26 of Set 9 | hamilton
# Processing Record 27 of Set 9 | kieta
# Processing Record 28 of Set 9 | rongcheng
# Processing Record 29 of Set 9 | kupang
# Processing Record 30 of Set 9 | puerto leguizamo
# Processing Record 31 of Set 9 | kjopsvik
# Processing Record 32 of Set 9 | tilichiki
# Processing Record 33 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 9 | chara
# Processing Record 35 of Set 9 | broome
# Processing Record 36 of Set 9 | sazonovo
# Processing Record 37 of Set 9 | laarne
# Processing Record 38 of Set 9 | big spring
# Processing Record 39 of Set 9 | college
# Processing Record 40 of Set 9 | sao joao da barra
# Processing Record 41 of Set 9 | hailar
# Processing Record 42 of Set 9 | salinopolis
# Processing Record 43 of Set 9 | hailey
# Processing Record 44 of Set 9 | tairua
# Processing Record 45 of Set 9 | carauari
# Processing Record 46 of Set 9 | qui nhon
# Processing Record 47 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 9 | lazaro cardenas
# Processing Record 49 of Set 9 | karpuninskiy
# City not found. Skipping...
# Processing Record 50 of Set 9 | tsurib
# Processing Record 1 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 2 of Set 10 | bouloupari
# Processing Record 3 of Set 10 | meulaboh
# Processing Record 4 of Set 10 | morristown
# Processing Record 5 of Set 10 | fort nelson
# Processing Record 6 of Set 10 | santa maria
# Processing Record 7 of Set 10 | berdigestyakh
# Processing Record 8 of Set 10 | sabha
# Processing Record 9 of Set 10 | mongagua
# Processing Record 10 of Set 10 | la ronge
# Processing Record 11 of Set 10 | verkhoyansk
# Processing Record 12 of Set 10 | poum
# Processing Record 13 of Set 10 | strelka
# Processing Record 14 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 15 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 10 | auki
# Processing Record 17 of Set 10 | carballo
# Processing Record 18 of Set 10 | unye
# City not found. Skipping...
# Processing Record 19 of Set 10 | tome-acu
# City not found. Skipping...
# Processing Record 20 of Set 10 | rudbar
# Processing Record 21 of Set 10 | nova olimpia
# Processing Record 22 of Set 10 | menzelinsk
# Processing Record 23 of Set 10 | nakapiripirit
# Processing Record 24 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 10 | farmington
# Processing Record 26 of Set 10 | yining
# Processing Record 27 of Set 10 | samarai
# Processing Record 28 of Set 10 | grindavik
# Processing Record 29 of Set 10 | kerman
# Processing Record 30 of Set 10 | chicama
# Processing Record 31 of Set 10 | jalu
# Processing Record 32 of Set 10 | ust-omchug
# Processing Record 33 of Set 10 | zhezkazgan
# Processing Record 34 of Set 10 | fuling
# Processing Record 35 of Set 10 | pakxan
# Processing Record 36 of Set 10 | te anau
# Processing Record 37 of Set 10 | benghazi
# Processing Record 38 of Set 10 | ugoofaaru
# Processing Record 39 of Set 10 | lubao
# Processing Record 40 of Set 10 | hongjiang
# Processing Record 41 of Set 10 | ciudad bolivar
# Processing Record 42 of Set 10 | candawaga
# City not found. Skipping...
# Processing Record 43 of Set 10 | port keats
# Processing Record 44 of Set 10 | acarau
# Processing Record 45 of Set 10 | starkville
# Processing Record 46 of Set 10 | bella union
# Processing Record 47 of Set 10 | adrar
# Processing Record 48 of Set 10 | kodiak
# Processing Record 49 of Set 10 | guacimo
# Processing Record 50 of Set 10 | baisha
# Processing Record 1 of Set 11 | owando
# Processing Record 2 of Set 11 | matay
# Processing Record 3 of Set 11 | butig
# Processing Record 4 of Set 11 | lauria
# Processing Record 5 of Set 11 | salalah
# Processing Record 6 of Set 11 | les cayes
# Processing Record 7 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 8 of Set 11 | batagay
# Processing Record 9 of Set 11 | haapiti
# Processing Record 10 of Set 11 | pacific grove
# Processing Record 11 of Set 11 | ancona
# Processing Record 12 of Set 11 | walcz
# Processing Record 13 of Set 11 | makhinjauri
# Processing Record 14 of Set 11 | grand gaube
# Processing Record 15 of Set 11 | ferlach
# Processing Record 16 of Set 11 | khislavichi
# Processing Record 17 of Set 11 | sosnovo-ozerskoye
# Processing Record 18 of Set 11 | ginir
# Processing Record 19 of Set 11 | cabo san lucas
# Processing Record 20 of Set 11 | hofn
# Processing Record 21 of Set 11 | plymouth
# Processing Record 22 of Set 11 | qingquan
# Processing Record 23 of Set 11 | moose factory
# Processing Record 24 of Set 11 | codrington
# Processing Record 25 of Set 11 | nsanje
# Processing Record 26 of Set 11 | alofi
# Processing Record 27 of Set 11 | ixtapa
# Processing Record 28 of Set 11 | linkuva
# Processing Record 29 of Set 11 | ust-kuyga
# Processing Record 30 of Set 11 | lebyazhye
# Processing Record 31 of Set 11 | caravelas
# Processing Record 32 of Set 11 | puerto baquerizo moreno
# Processing Record 33 of Set 11 | tyulyachi
# Processing Record 34 of Set 11 | mezhova
# Processing Record 35 of Set 11 | ta khmau
# Processing Record 36 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 11 | kuntaur
# Processing Record 38 of Set 11 | cedral
# Processing Record 39 of Set 11 | avera
# Processing Record 40 of Set 11 | itarema
# Processing Record 41 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 42 of Set 11 | celestun
# Processing Record 43 of Set 11 | curuca
# Processing Record 44 of Set 11 | baherden
# Processing Record 45 of Set 11 | kirakira
# Processing Record 46 of Set 11 | vila
# Processing Record 47 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 11 | ejutla de crespo
# Processing Record 49 of Set 11 | olafsvik
# Processing Record 50 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 2 of Set 12 | shiloh
# Processing Record 3 of Set 12 | northam
# Processing Record 4 of Set 12 | tagusao
# Processing Record 5 of Set 12 | wamba
# Processing Record 6 of Set 12 | larkollen
# Processing Record 7 of Set 12 | pontianak
# Processing Record 8 of Set 12 | biankouma
# Processing Record 9 of Set 12 | anrochte
# Processing Record 10 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 12 | seversk
# Processing Record 12 of Set 12 | lompoc
# Processing Record 13 of Set 12 | kungurtug
# Processing Record 14 of Set 12 | aketi
# Processing Record 15 of Set 12 | arauco
# Processing Record 16 of Set 12 | dimitrovgrad
# Processing Record 17 of Set 12 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 18 of Set 12 | ponerihouen
# Processing Record 19 of Set 12 | gezing
# Processing Record 20 of Set 12 | nobres
# Processing Record 21 of Set 12 | hobyo
# Processing Record 22 of Set 12 | rochefort
# Processing Record 23 of Set 12 | sitka
# Processing Record 24 of Set 12 | ewa beach
# Processing Record 25 of Set 12 | praia
# Processing Record 26 of Set 12 | umea
# Processing Record 27 of Set 12 | alugan
# Processing Record 28 of Set 12 | lac du bonnet
# Processing Record 29 of Set 12 | skiros
# City not found. Skipping...
# Processing Record 30 of Set 12 | husavik
# Processing Record 31 of Set 12 | pisco
# Processing Record 32 of Set 12 | tshikapa
# Processing Record 33 of Set 12 | aginskoye
# Processing Record 34 of Set 12 | locri
# Processing Record 35 of Set 12 | tuxpan
# Processing Record 36 of Set 12 | komsomolskiy
# Processing Record 37 of Set 12 | hargeysa
# Processing Record 38 of Set 12 | bajil
# Processing Record 39 of Set 12 | dordrecht
# Processing Record 40 of Set 12 | strezhevoy
# Processing Record 41 of Set 12 | baglan
# Processing Record 42 of Set 12 | jieshi
# Processing Record 43 of Set 12 | caceres
# Processing Record 44 of Set 12 | souillac
# Processing Record 45 of Set 12 | tutoia
# Processing Record 46 of Set 12 | gistrup
# Processing Record 47 of Set 12 | saint-pierre
# Processing Record 48 of Set 12 | stephenville
# Processing Record 49 of Set 12 | kosya
# City not found. Skipping...
# Processing Record 50 of Set 12 | kpandu
# Processing Record 1 of Set 13 | utena
# Processing Record 2 of Set 13 | vyshneve
# Processing Record 3 of Set 13 | eureka
# Processing Record 4 of Set 13 | eyl
# Processing Record 5 of Set 13 | plettenberg bay
# Processing Record 6 of Set 13 | salsomaggiore terme
# Processing Record 7 of Set 13 | clyde river
# Processing Record 8 of Set 13 | bhadasar
# Processing Record 9 of Set 13 | villa alemana
# Processing Record 10 of Set 13 | ormara
# Processing Record 11 of Set 13 | tingi
# Processing Record 12 of Set 13 | tessalit
# Processing Record 13 of Set 13 | kaeo
# Processing Record 14 of Set 13 | port hedland
# Processing Record 15 of Set 13 | palmer
# Processing Record 16 of Set 13 | kaseda
# Processing Record 17 of Set 13 | dien bien
# City not found. Skipping...
# Processing Record 18 of Set 13 | toyooka
# Processing Record 19 of Set 13 | myitkyina
# Processing Record 20 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 21 of Set 13 | milkovo
# Processing Record 22 of Set 13 | kalianget
# Processing Record 23 of Set 13 | taltal
# Processing Record 24 of Set 13 | reconquista
# Processing Record 25 of Set 13 | xining
# Processing Record 26 of Set 13 | darhan
# Processing Record 27 of Set 13 | takoradi
# Processing Record 28 of Set 13 | zdvinsk
# Processing Record 29 of Set 13 | saldanha
# Processing Record 30 of Set 13 | bouza
# Processing Record 31 of Set 13 | bridlington
# Processing Record 32 of Set 13 | knyaginino
# Processing Record 33 of Set 13 | ayan
# Processing Record 34 of Set 13 | nalut
# Processing Record 35 of Set 13 | altamira
# Processing Record 36 of Set 13 | moyale
# Processing Record 37 of Set 13 | smidovich
# Processing Record 38 of Set 13 | puerto narino
# Processing Record 39 of Set 13 | kudahuvadhoo
# Processing Record 40 of Set 13 | sabang
# Processing Record 41 of Set 13 | zhaotong
# Processing Record 42 of Set 13 | bondoukou
# Processing Record 43 of Set 13 | camacupa
# Processing Record 44 of Set 13 | buraydah
# Processing Record 45 of Set 13 | bardiyah
# Processing Record 46 of Set 13 | santana do livramento
# Processing Record 47 of Set 13 | coihaique
# Processing Record 48 of Set 13 | ushtobe
# Processing Record 49 of Set 13 | port moresby
# Processing Record 50 of Set 13 | kutum
# Processing Record 1 of Set 14 | phuket
# Processing Record 2 of Set 14 | mount pleasant
# Processing Record 3 of Set 14 | swan river
# Processing Record 4 of Set 14 | lorengau
# Processing Record 5 of Set 14 | olinda
# Processing Record 6 of Set 14 | zhigansk
# Processing Record 7 of Set 14 | viransehir
# Processing Record 8 of Set 14 | port augusta
# Processing Record 9 of Set 14 | sohag
# Processing Record 10 of Set 14 | los llanos de aridane
# Processing Record 11 of Set 14 | finschhafen
# Processing Record 12 of Set 14 | mildura
# Processing Record 13 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 14 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 14 | sao jose da coroa grande
# Processing Record 16 of Set 14 | shache
# Processing Record 17 of Set 14 | grafton
# Processing Record 18 of Set 14 | merzifon
# Processing Record 19 of Set 14 | natal
# Processing Record 20 of Set 14 | padilla
# Processing Record 21 of Set 14 | constantine
# Processing Record 22 of Set 14 | black river
# Processing Record 23 of Set 14 | havelock
# Processing Record 24 of Set 14 | galich
# Processing Record 25 of Set 14 | luwuk
# Processing Record 26 of Set 14 | zhangye
# Processing Record 27 of Set 14 | saint-augustin
# Processing Record 28 of Set 14 | maniitsoq
# Processing Record 29 of Set 14 | allanridge
# Processing Record 30 of Set 14 | penzance
# Processing Record 31 of Set 14 | chupei
# City not found. Skipping...
# Processing Record 32 of Set 14 | kralendijk
# Processing Record 33 of Set 14 | necochea
# Processing Record 34 of Set 14 | farias brito
# Processing Record 35 of Set 14 | seoul
# Processing Record 36 of Set 14 | karasjok
# Processing Record 37 of Set 14 | la libertad
# Processing Record 38 of Set 14 | ulaanbaatar
# Processing Record 39 of Set 14 | ifakara
# Processing Record 40 of Set 14 | meilu
# City not found. Skipping...
# Processing Record 41 of Set 14 | leningradskiy
# Processing Record 42 of Set 14 | lisakovsk
# Processing Record 43 of Set 14 | haines junction
# Processing Record 44 of Set 14 | sarankhola
# Processing Record 45 of Set 14 | kokkola
# Processing Record 46 of Set 14 | peniche
# Processing Record 47 of Set 14 | brigantine
# Processing Record 48 of Set 14 | luganville
# Processing Record 49 of Set 14 | melipilla
# Processing Record 50 of Set 14 | vostok
# Processing Record 1 of Set 15 | manati
# Processing Record 2 of Set 15 | kahului
# Processing Record 3 of Set 15 | dawlatabad
# Processing Record 4 of Set 15 | kimberley
# Processing Record 5 of Set 15 | lagos
# Processing Record 6 of Set 15 | wloclawek
# Processing Record 7 of Set 15 | whitehorse
# Processing Record 8 of Set 15 | kampene
# Processing Record 9 of Set 15 | namatanai
# Processing Record 10 of Set 15 | kollumerland
# City not found. Skipping...
# Processing Record 11 of Set 15 | port hardy
# Processing Record 12 of Set 15 | bubaque
# Processing Record 13 of Set 15 | borovskoy
# Processing Record 14 of Set 15 | ostroleka
# Processing Record 15 of Set 15 | la romana
# Processing Record 16 of Set 15 | kavaratti
# Processing Record 17 of Set 15 | namuac
# Processing Record 18 of Set 15 | guatire
# Processing Record 19 of Set 15 | valparaiso
# Processing Record 20 of Set 15 | sechura
# Processing Record 21 of Set 15 | north platte
# Processing Record 22 of Set 15 | fernandez
# Processing Record 23 of Set 15 | awjilah
# Processing Record 24 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 25 of Set 15 | kinablangan
# Processing Record 26 of Set 15 | boa vista
# Processing Record 27 of Set 15 | aksarka
# Processing Record 28 of Set 15 | leshukonskoye
# Processing Record 29 of Set 15 | abu dhabi
# Processing Record 30 of Set 15 | kindu
# Processing Record 31 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 15 | raga
# Processing Record 33 of Set 15 | soe
# Processing Record 34 of Set 15 | stokmarknes
# Processing Record 35 of Set 15 | senges
# Processing Record 36 of Set 15 | kasongo-lunda
# Processing Record 37 of Set 15 | dunedin
# Processing Record 38 of Set 15 | puerto parra
# Processing Record 39 of Set 15 | mandalgovi
# Processing Record 40 of Set 15 | santa marta
# Processing Record 41 of Set 15 | ito
# Processing Record 42 of Set 15 | takaungu
# Processing Record 43 of Set 15 | tekirdag
# Processing Record 44 of Set 15 | acaponeta
# Processing Record 45 of Set 15 | samana
# Processing Record 46 of Set 15 | nioro
# Processing Record 47 of Set 15 | la cruz
# Processing Record 48 of Set 15 | lethem
# Processing Record 49 of Set 15 | ban chang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Kashary      RU  49.0400   41.0056     79.68        48          33
# 1   Havelange      BE  50.3833    5.2333     55.67        96          25
# 2    Ngunguru      NZ -35.6167  174.5000     64.17        61          33
# 3       Kenai      US  60.5544 -151.2583     74.03        49           1
# 4  Los Chiles      CR  11.0333  -84.7167     74.08        95         100
#
#    Wind Speed Current Description
# 0        3.15    scattered clouds
# 1        4.47    scattered clouds
# 2        8.81    scattered clouds
# 3        9.22           clear sky
# 4        2.91     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
